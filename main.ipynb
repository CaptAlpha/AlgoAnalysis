# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Algo.csv')
df
# Out:
#    SampleSize  BubbleSort   SelectionSort  InsertionSort  MergeSort  QuickSort
# 0        1000        0.010          0.002          0.001      0.000      0.000
# 1        5000        0.069          0.038          0.020      0.001      0.000
# 2       10000        0.285          0.154          0.076      0.002      0.001
# 3       50000        8.734          3.338          1.812      0.012      0.011
# 4      100000       32.080         12.966          6.990      0.022      0.022
# 5      200000      128.921         52.440         28.437      0.044      0.044

# %%
x = df.iloc[:, 0]
df.iloc[:, 1:6] = np.log(df.iloc[:, 1:6])

# %%
plt.loglog(x, y, "-o")

# %%
y = np.log(y)

# %%
y_log
# Out:
#    BubbleSort   SelectionSort  InsertionSort  MergeSort  QuickSort
# 0    -4.605170      -6.214608      -6.907755       -inf       -inf
# 1    -2.673649      -3.270169      -3.912023  -6.907755       -inf
# 2    -1.255266      -1.870803      -2.577022  -6.214608  -6.907755
# 3     2.167223       1.205372       0.594431  -4.422849  -4.509860
# 4     3.468233       2.562331       1.944481  -3.816713  -3.816713
# 5     4.859200       3.959670       3.347691  -3.123566  -3.123566

# %%
plt.plot(y_log)

# %%
fig = df.set_index('SampleSize').plot()
